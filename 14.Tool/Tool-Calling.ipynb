# %%
from langchain_cohere import ChatCohere
from langchain_core.tools import tool
from langchain_core.messages import HumanMessage
from dotenv import load_dotenv
import requests

# %%
# create tool
@tool
def multiply(a:int, b:int) -> int:
    """Given 2 numbers a and b this tool return their product"""
    return a*b

# %%
print(multiply.invoke({'a':2,'b':5}))
# Out:
# 10

# %%
load_dotenv()
llm = ChatCohere(model="command-a-03-2025")

# %%
#tool binding
llm_with_tools = llm.bind_tools([multiply])

# %%
#tool calling
query = HumanMessage('can you multiply 5 with 2')

# %%
message =[query]

# %%
message
# Out:
# [HumanMessage(content='can you multiply 5 with 2', additional_kwargs={}, response_metadata={})]

# %%
result = llm_with_tools.invoke(message)

# %%
message.append(result)

# %%
message
# Out:
# [HumanMessage(content='can you multiply 5 with 2', additional_kwargs={}, response_metadata={}),
#  AIMessage(content='I will use the multiply tool to multiply 5 with 2.', additional_kwargs={'id': '50dd0365-dae1-4210-a3c6-c5fdfcf88276', 'finish_reason': 'TOOL_CALL', 'tool_plan': 'I will use the multiply tool to multiply 5 with 2.', 'tool_calls': [{'id': 'multiply_w7xe4qcxw1pt', 'type': 'function', 'function': {'name': 'multiply', 'arguments': '{"a":5,"b":2}'}}], 'token_count': {'input_tokens': 1452.0, 'output_tokens': 55.0}}, response_metadata={'id': '50dd0365-dae1-4210-a3c6-c5fdfcf88276', 'finish_reason': 'TOOL_CALL', 'tool_plan': 'I will use the multiply tool to multiply 5 with 2.', 'tool_calls': [{'id': 'multiply_w7xe4qcxw1pt', 'type': 'function', 'function': {'name': 'multiply', 'arguments': '{"a":5,"b":2}'}}], 'token_count': {'input_tokens': 1452.0, 'output_tokens': 55.0}}, id='lc_run--d3319343-3526-4f13-ae1e-66631107e555-0', tool_calls=[{'name': 'multiply', 'args': {'a': 5, 'b': 2}, 'id': 'multiply_w7xe4qcxw1pt', 'type': 'tool_call'}], usage_metadata={'input_tokens': 1452, 'output_tokens': 55, 'total_tokens': 1507})]

# %%
tool_result = multiply.invoke(result.tool_calls[0])

# %%
message.append(tool_result)

# %%
message
# Out:
# [HumanMessage(content='can you multiply 5 with 2', additional_kwargs={}, response_metadata={}),
#  AIMessage(content='I will use the multiply tool to multiply 5 with 2.', additional_kwargs={'id': '50dd0365-dae1-4210-a3c6-c5fdfcf88276', 'finish_reason': 'TOOL_CALL', 'tool_plan': 'I will use the multiply tool to multiply 5 with 2.', 'tool_calls': [{'id': 'multiply_w7xe4qcxw1pt', 'type': 'function', 'function': {'name': 'multiply', 'arguments': '{"a":5,"b":2}'}}], 'token_count': {'input_tokens': 1452.0, 'output_tokens': 55.0}}, response_metadata={'id': '50dd0365-dae1-4210-a3c6-c5fdfcf88276', 'finish_reason': 'TOOL_CALL', 'tool_plan': 'I will use the multiply tool to multiply 5 with 2.', 'tool_calls': [{'id': 'multiply_w7xe4qcxw1pt', 'type': 'function', 'function': {'name': 'multiply', 'arguments': '{"a":5,"b":2}'}}], 'token_count': {'input_tokens': 1452.0, 'output_tokens': 55.0}}, id='lc_run--d3319343-3526-4f13-ae1e-66631107e555-0', tool_calls=[{'name': 'multiply', 'args': {'a': 5, 'b': 2}, 'id': 'multiply_w7xe4qcxw1pt', 'type': 'tool_call'}], usage_metadata={'input_tokens': 1452, 'output_tokens': 55, 'total_tokens': 1507}),
#  ToolMessage(content='10', name='multiply', tool_call_id='multiply_w7xe4qcxw1pt')]

# %%
llm_with_tools.invoke(message).content
# Out:
# '10 is the result of multiplying 5 with 2.'
