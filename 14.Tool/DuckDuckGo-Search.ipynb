# %%
from langchain_community.tools import DuckDuckGoSearchRun

search_tool = DuckDuckGoSearchRun()

results = search_tool.invoke('KIIT')

print(results)
# Out:
# Succumbing to the students’ demand, the two women officials, Janati Nath and Manjusha Pande, issued a video message in KIIT ’s official X post and tendered an apology. Concerns and challenges related to SIR, third suicide case reported at KIIT , Bhubaneshwar, and government and opposition reach an agreement. KIIT University issued a statement expressing shock over the student’s death, describing it as “extremely sad and unfortunate." Odisha: 18-year-old KIIT student commits suicide, case registered. KIIT shock: First-year BTech student found hanging in hostel, third death on Bhubaneswar campus this year. KIIT issued a notice saying, “The university is closed sine die for all the international students from Nepal. They are hereby directed to vacate the university campus immediately today on...

# %%
from langchain_community.tools import ShellTool

search_tool = ShellTool()

results = search_tool.invoke('ls')

print(results)
# Out:
# Executing command:
#  ls
# DuckDuckGo-Search.ipynb
