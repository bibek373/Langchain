# %%
from langchain_cohere import CohereEmbeddings
from langchain_community.vectorstores import FAISS
from langchain_core.documents import Document
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
embeddings = CohereEmbeddings(model  ="embed-english-v3.0")

# %%
doc1 = Document(
    page_content="Virat Kohli is one of the most successful and consistent batsmen in IPL history. Known for his aggressive batting style and leadership.",
    metadata={"team": "Royal Challengers Bangalore"}
)

doc2 = Document(
    page_content="Rohit Sharma is the most successful captain in IPL history, leading Mumbai Indians to five titles. He's known for his calm captaincy and explosive batting.",
    metadata={"team": "Mumbai Indians"}
)

doc3 = Document(
    page_content="MS Dhoni, also known as Captain Cool, has led Chennai Super Kings to multiple IPL victories. Famous for his finishing ability and strategic mind.",
    metadata={"team": "Chennai Super Kings"}
)

doc4 = Document(
    page_content="Jasprit Bumrah is one of the best T20 fast bowlers. Playing for Mumbai Indians, he is known for yorkers, pace variations, and match-winning spells.",
    metadata={"team": "Mumbai Indians"}
)

doc5 = Document(
    page_content="Rashid Khan is an exceptional leg-spinner who plays for Gujarat Titans. His quick arm action, googlies, and consistency make him a top T20 bowler.",
    metadata={"team": "Gujarat Titans"}
)

docs = [doc1,doc2,doc3,doc4,doc5]

# %%
vector_store = FAISS.from_documents(docs,embeddings)

# %%
vector_store.save_local('faiss_db')

# %%
vector_store.similarity_search('who is the bowler ', k=2)
# Out:
# [Document(id='1c922830-26c1-40c0-bed8-83a14fe14e57', metadata={'team': 'Mumbai Indians'}, page_content='Jasprit Bumrah is one of the best T20 fast bowlers. Playing for Mumbai Indians, he is known for yorkers, pace variations, and match-winning spells.'),
#  Document(id='ec87bb9e-3725-4ffa-a349-5a9ec484c19a', metadata={'team': 'Gujarat Titans'}, page_content='Rashid Khan is an exceptional leg-spinner who plays for Gujarat Titans. His quick arm action, googlies, and consistency make him a top T20 bowler.')]

# %%
docs = vector_store.similarity_search("", k=1000)

for i, d in enumerate(docs, start=1):
    print(f"\n--- DOC {i} ---")
    print("ID:", d.metadata.get("id") if isinstance(d.metadata, dict) else None)
    print("METADATA:", d.metadata)
    print("CONTENT:", d.page_content)
# Out:
# --- DOC 1 ---
# ID: None
# METADATA: {'team': 'Gujarat Titans'}
# CONTENT: Rashid Khan is an exceptional leg-spinner who plays for Gujarat Titans. His quick arm action, googlies, and consistency make him a top T20 bowler.
# page_content='Rashid Khan is an exceptional leg-spinner who plays for Gujarat Titans. His quick arm action, googlies, and consistency make him a top T20 bowler.' metadata={'team': 'Gujarat Titans'}
#
# --- DOC 2 ---
# ID: None
# METADATA: {'team': 'Chennai Super Kings'}
# CONTENT: MS Dhoni, also known as Captain Cool, has led Chennai Super Kings to multiple IPL victories. Famous for his finishing ability and strategic mind.
# page_content='MS Dhoni, also known as Captain Cool, has led Chennai Super Kings to multiple IPL victories. Famous for his finishing ability and strategic mind.' metadata={'team': 'Chennai Super Kings'}
#
# --- DOC 3 ---
# ID: None
# METADATA: {'team': 'Mumbai Indians'}
# CONTENT: Jasprit Bumrah is one of the best T20 fast bowlers. Playing for Mumbai Indians, he is known for yorkers, pace variations, and match-winning spells.
# page_content='Jasprit Bumrah is one of the best T20 fast bowlers. Playing for Mumbai Indians, he is known for yorkers, pace variations, and match-winning spells.' metadata={'team': 'Mumbai Indians'}
#
# --- DOC 4 ---
# ID: None
# METADATA: {'team': 'Royal Challengers Bangalore'}
# CONTENT: Virat Kohli is one of the most successful and consistent batsmen in IPL history. Known for his aggressive batting style and leadership.
# page_content='Virat Kohli is one of the most successful and consistent batsmen in IPL history. Known for his aggressive batting style and leadership.' metadata={'team': 'Royal Challengers Bangalore'}
#
# --- DOC 5 ---
# ID: None
# METADATA: {'team': 'Mumbai Indians'}
# CONTENT: Rohit Sharma is the most successful captain in IPL history, leading Mumbai Indians to five titles. He's known for his calm captaincy and explosive batting.
# page_content='Rohit Sharma is the most successful captain in IPL history, leading Mumbai Indians to five titles. He's known for his calm captaincy and explosive batting.' metadata={'team': 'Mumbai Indians'}
